# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_pd=pd.read_csv("train.csv")

# %%
test_pd=pd.read_csv("test.csv")

# %%
train_pd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test_pd
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
survived = train_pd["Survived"]

# %%
train_pd = train_pd.drop(["Survived"], axis=1)
train_pd
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
train_idx=train_pd["PassengerId"]
test_idx=test_pd["PassengerId"]

# %%
combined_pd=pd.concat([train_pd,test_pd]).reset_index(drop=True)

# %%
combined_pd
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male   NaN      0      0              359309    8.0500   NaN        S
# 1308    male   NaN      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %%
combined_pd.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
y=combined_pd["Age"].value_counts()
y
# Out:
# Age
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: count, Length: 98, dtype: int64

# %%
x=y.index.values
x
# Out:
# array([24.  , 22.  , 21.  , 30.  , 18.  , 25.  , 28.  , 36.  , 29.  ,
#        27.  , 26.  , 19.  , 23.  , 32.  , 31.  , 20.  , 35.  , 33.  ,
#        45.  , 39.  , 17.  , 16.  , 40.  , 42.  , 34.  , 50.  , 47.  ,
#        38.  , 48.  ,  2.  , 41.  ,  1.  , 44.  , 54.  ,  9.  ,  4.  ,
#        49.  , 43.  , 37.  , 51.  , 55.  , 14.  , 60.  ,  3.  , 58.  ,
#        46.  , 15.  ,  8.  ,  6.  , 52.  , 62.  , 61.  ,  5.  , 64.  ,
#        57.  , 13.  , 63.  , 10.  , 53.  , 32.5 , 56.  ,  7.  , 11.  ,
#        59.  , 18.5 , 40.5 , 65.  ,  0.75, 28.5 ,  0.83, 12.  , 14.5 ,
#        36.5 , 45.5 , 30.5 , 70.  , 71.  , 34.5 ,  0.92, 11.5 ,  0.17,
#        60.5 , 26.5 , 76.  , 67.  , 22.5 ,  0.33, 80.  , 74.  ,  0.42,
#         0.67, 66.  , 24.5 , 23.5 , 70.5 , 55.5 , 20.5 , 38.5 ])

# %%
y=combined_pd["Age"].value_counts()
x=y.index.values

plt.figure(figsize=(10,5))
plt.bar(x,y)
plt.title("All Age")
plt.show()

# %%
class_age=combined_pd[["Pclass","Age"]]

for i in range(1,4):
    plt.figure(figsize=(10,5))
    plt.title("Class"+str(i))
    y=class_age[class_age["Pclass"]==i]["Age"].value_counts() 
    x=y.index.values

    plt.bar(x,y)
    plt.show()

# %%
medians=class_age.groupby("Pclass").median()
medians
# Out:
#          Age
# Pclass
# 1       39.0
# 2       29.0
# 3       24.0

# %%
for i in range(3):
    idx = np.where((combined_pd["Pclass"]==i+1) & (combined_pd["Age"].isnull()))[0]
    combined_pd.loc[idx,"Age"]=medians.values[i][0]
    
combined_pd
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male  24.0      0      0              359309    8.0500   NaN        S
# 1308    male  24.0      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %%
combined_pd[combined_pd["Fare"].isnull()]
# Out:
#       PassengerId  Pclass                Name   Sex   Age  SibSp  Parch  \
# 1043         1044       3  Storey, Mr. Thomas  male  60.5      0      0
#
#      Ticket  Fare Cabin Embarked
# 1043   3701   NaN   NaN        S

# %%
sim_fares=combined_pd[(combined_pd["Pclass"]==3) &(combined_pd["Embarked"]=="S")]["Fare"]

# %%
sim_fares.median()
# Out:
# 8.05

# %%
plt.hist(sim_fares)
plt.plot()
# Out:
# []

# %%
combined_pd["Fare"].fillna(sim_fares.median(),inplace=True)
# Out:
# C:\Users\karat\AppData\Local\Temp\ipykernel_17040\846943832.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_pd["Fare"].fillna(sim_fares.median(),inplace=True)

# %%
combined_pd[combined_pd["Fare"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
combined_pd[combined_pd["Embarked"].isnull()]
# Out:
#      PassengerId  Pclass                                       Name     Sex  \
# 61            62       1                        Icard, Miss. Amelie  female
# 829          830       1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   38.0      0      0  113572  80.0   B28      NaN
# 829  62.0      0      0  113572  80.0   B28      NaN

# %%
sim_emb = combined_pd[(combined_pd["Pclass"]==1) &(combined_pd["Fare"]>=70)&(combined_pd["Fare"]<=90)]["Embarked"]
sim_emb.value_counts()
# Out:
# Embarked
# C    29
# S    25
# Q     3
# Name: count, dtype: int64

# %%
combined_pd["Embarked"].fillna("C",inplace=True)
# Out:
# C:\Users\karat\AppData\Local\Temp\ipykernel_17040\3213101974.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_pd["Embarked"].fillna("C",inplace=True)

# %%
combined_pd[combined_pd["Embarked"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
combined_pd['Cabin'].fillna("M", inplace=True)
combined_pd["Cabin"]=combined_pd["Cabin"].str[0]

combined_pd["Cabin"].value_counts()

idx=np.where(combined_pd["Cabin"]=="T")[0]
combined_pd.loc[idx,"Cabin"]="M"
# Out:
# C:\Users\karat\AppData\Local\Temp\ipykernel_17040\3804926886.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_pd['Cabin'].fillna("M", inplace=True)

# %%
 combined_pd
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500     M        S
# 1     female  38.0      1      0            PC 17599   71.2833     C        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250     M        S
# 3     female  35.0      1      0              113803   53.1000     C        S
# 4       male  35.0      0      0              373450    8.0500     M        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500     M        S
# 1305  female  39.0      0      0            PC 17758  108.9000     C        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500     M        S
# 1307    male  24.0      0      0              359309    8.0500     M        S
# 1308    male  24.0      1      1                2668   22.3583     M        C
#
# [1309 rows x 11 columns]

# %%
combined_pd.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
